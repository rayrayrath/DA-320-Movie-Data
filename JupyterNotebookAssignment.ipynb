# %% [markdown]
# DA 320
# Assignment Jupyter Notebook
# Rachel Rathgeber

# %% [markdown]
# DA 320
# Rachel Rathgeber
# Jupyter Notebooks Assigment

# %%
import http
import urllib3
import certifi
import re
import pandas as pd


#indetifying the website to be used for information gathering
link= "https://www.metacritic.com/browse/movies/score/metascore/year/filtered?year_selected=2002&sort=desc&view=detailed"

#Construct a python request pool and work around for the authentication certificate
http = urllib3.PoolManager(cert_reqs = 'CERT_NONE')

urllib3.disable_warnings()

res = http.request('GET', link, headers={'User-Agent':'Mozilla/5.0'})

#Convert the result from raw bytes to text
datastring = str(res.data, "utf-8")

#searches site for the requested data
movieTitle = re.findall('class="title"><h3>(.*)<\/h3>', datastring)
releaseDate = re.findall('<div class="clamp-details">\s*<span>(.*?)<\/span>', datastring)
description = re.findall('<div class="summary">\s(.*)', datastring)
metascore = re.findall('<div class="clamp-score-wrap">\s*.*\s<div class="metascore_w large movie positive">(\d\d)', datastring)
photo = re.findall('<a href=".*<img\ssrc="(https.*)" alt', datastring)

#Formats the data into a readable table
#Stored data to the dataframe
data = [movieTitle, releaseDate, description, metascore, photo]
df= pd.DataFrame(data)
#I tried to use Prettytables but it wasn't looking right and was taking me too long so I gave up on it and went with the simple dataframe
print('Top 100 Movies of 2002')
#print dataframe
df
# Out:
# Top 100 Movies of 2002
#                                                   0   \
# 0                                      Spirited Away
# 1                                 September 20, 2002
# 2                          A young girl, Chihiro,...
# 3                                                 96
# 4  https://static.metacritic.com/images/products/...
#
#                                                   1   \
# 0                        Atanarjuat: The Fast Runner
# 1                                       June 7, 2002
# 2                          Evil in the form of an...
# 3                                                 91
# 4  https://static.metacritic.com/images/products/...
#
#                                                   2   \
# 0                                      Bloody Sunday
# 1                                    October 4, 2002
# 2                          This controversial and...
# 3                                                 90
# ...

# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 14.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.8/500.8 kB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 20.2 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.
